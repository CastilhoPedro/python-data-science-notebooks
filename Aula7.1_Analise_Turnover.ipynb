# %% [markdown]
# # Árvores de Decisão: Classificação

# %% [markdown]
# ## Modelo de Análise de Turnover

# %%
df = pd.read_csv('base_rh.csv')
df.head()
# Out:
#   Funcionario_Deixou_Empresa          Freq_Viagens  ... Idade Tempo_de_empresa
# 0                        Sim       Viaja raramente  ...    41                6
# 1                        Não  Viaja frequentemente  ...    49               10
# 2                        Sim       Viaja raramente  ...    37                0
# 3                        Não  Viaja frequentemente  ...    33                8
# 4                        Não       Viaja raramente  ...    27                2
#
# [5 rows x 8 columns]

# %%
sns.pairplot(df, hue='Funcionario_Deixou_Empresa')

# %%
df['Target'] = np.where(df['Funcionario_Deixou_Empresa'] == 'Sim', 1, 0)

# %%
df.head()
# Out:
#   Funcionario_Deixou_Empresa          Freq_Viagens  ... Tempo_de_empresa Target
# 0                        Sim       Viaja raramente  ...                6      1
# 1                        Não  Viaja frequentemente  ...               10      0
# 2                        Sim       Viaja raramente  ...                0      1
# 3                        Não  Viaja frequentemente  ...                8      0
# 4                        Não       Viaja raramente  ...                2      0
#
# [5 rows x 9 columns]

# %%
df_iv = analise_iv(df, target= 'Target')
df_iv.get_lista_iv()
# Out:
# /content/aed_novo.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num[nome_var] = pd.qcut(df_num[var],
# /content/aed_novo.py:32: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df2 = df_aux.pivot_table(values='target2',
# /content/aed_novo.py:32: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df2 = df_aux.pivot_table(values='target2',
# Target                        IV
# Variavel
# Funcionario_Deixou_Empresa  9.21
# Faz_hora_extras             0.40
# Tempo_de_empresa            0.34
# Idade                       0.31
# Estado_Civil                0.22
# Freq_Viagens                0.13
# Equilibrio_de_Vida          0.06
# Formacao                    0.01

# %% [markdown]
# ### Criação das variáveis dummies

# %%
df_dummies = pd.get_dummies(df)
df_dummies.head()
# Out:
#    Idade  ...  Equilibrio_de_Vida_Ruim
# 0     41  ...                     True
# 1     49  ...                    False
# 2     37  ...                    False
# 3     33  ...                    False
# 4     27  ...                    False
#
# [5 rows x 22 columns]

# %%
# Var Target
y = df_dummies['Target']

# Features
x = df_dummies.drop(['Target', 'Funcionario_Deixou_Empresa_Não', 'Funcionario_Deixou_Empresa_Sim'], axis=1)

# %% [markdown]
# ### Criação do Modelo

# %%
model = DecisionTreeClassifier(max_depth=4, random_state=42)
model.fit(x, y)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
# Avaliação do Modelo treinado
plt.figure(figsize=(20, 10))
plt.title('Arvore de Decisão')
tree.plot_tree(model, feature_names=x.columns, filled=True, class_names=['Não Turnover', 'Turnover'])
# Out:
# [Text(0.5, 0.9, 'Faz_hora_extras_Sim <= 0.5\ngini = 0.27\nsamples = 1470\nvalue = [1233.0, 237.0]\nclass = Não Turnover'),
#  Text(0.25, 0.7, 'Tempo_de_empresa <= 1.5\ngini = 0.187\nsamples = 1054\nvalue = [944, 110]\nclass = Não Turnover'),
#  Text(0.375, 0.8, 'True  '),
#  Text(0.125, 0.5, 'Idade <= 32.5\ngini = 0.378\nsamples = 146\nvalue = [109, 37]\nclass = Não Turnover'),
#  Text(0.0625, 0.3, 'Freq_Viagens_Viaja frequentemente <= 0.5\ngini = 0.493\nsamples = 68\nvalue = [38, 30]\nclass = Não Turnover'),
#  Text(0.03125, 0.1, 'gini = 0.459\nsamples = 56\nvalue = [36, 20]\nclass = Não Turnover'),
#  Text(0.09375, 0.1, 'gini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Turnover'),
#  Text(0.1875, 0.3, 'Equilibrio_de_Vida_Ruim <= 0.5\ngini = 0.163\nsamples = 78\nvalue = [71, 7]\nclass = Não Turnover'),
#  Text(0.15625, 0.1, 'gini = 0.128\nsamples = 73\nvalue = [68, 5]\nclass = Não Turnover'),
#  Text(0.21875, 0.1, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Não Turnover'),
#  Text(0.375, 0.5, 'Equilibrio_de_Vida_Ruim <= 0.5\ngini = 0.148\nsamples = 908\nvalue = [835, 73]\nclass = Não Turnover'),
#  Text(0.3125, 0.3, 'Tempo_de_empresa <= 38.5\ngini = 0.134\nsamples = 859\nvalue = [797.0, 62.0]\nclass = Não Turnover'),
#  Text(0.28125, 0.1, 'gini = 0.132\nsamples = 858\nvalue = [797.0, 61.0]\nclass = Não Turnover'),
#  Text(0.34375, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Turnover'),
#  Text(0.4375, 0.3, 'Tempo_de_empresa <= 8.5\ngini = 0.348\nsamples = 49\nvalue = [38, 11]\nclass = Não Turnover'),
#  Text(0.40625, 0.1, 'gini = 0.251\nsamples = 34\nvalue = [29, 5]\nclass = Não Turnover'),
#  Text(0.46875, 0.1, 'gini = 0.48\nsamples = 15\nvalue = [9, 6]\nclass = Não Turnover'),
#  Text(0.75, 0.7, 'Estado_Civil_Solteiro <= 0.5\ngini = 0.424\nsamples = 416\nvalue = [289.0, 127.0]\nclass = Não Turnover'),
#  Text(0.625, 0.8, '  False'),
#  Text(0.625, 0.5, 'Tempo_de_empresa <= 3.5\ngini = 0.34\nsamples = 285\nvalue = [223, 62]\nclass = Não Turnover'),
#  Text(0.5625, 0.3, 'Idade <= 29.5\ngini = 0.472\nsamples = 89\nvalue = [55.0, 34.0]\nclass = Não Turnover'),
#  Text(0.53125, 0.1, 'gini = 0.444\nsamples = 24\nvalue = [8, 16]\nclass = Turnover'),
#  Text(0.59375, 0.1, 'gini = 0.4\nsamples = 65\nvalue = [47, 18]\nclass = Não Turnover'),
#  Text(0.6875, 0.3, 'Formacao_Mestrado <= 0.5\ngini = 0.245\nsamples = 196\nvalue = [168, 28]\nclass = Não Turnover'),
#  Text(0.65625, 0.1, 'gini = 0.179\nsamples = 141\nvalue = [127, 14]\nclass = Não Turnover'),
#  Text(0.71875, 0.1, 'gini = 0.38\nsamples = 55\nvalue = [41.0, 14.0]\nclass = Não Turnover'),
#  Text(0.875, 0.5, 'Idade <= 34.5\ngini = 0.5\nsamples = 131\nvalue = [66, 65]\nclass = Não Turnover'),
#  Text(0.8125, 0.3, 'Tempo_de_empresa <= 1.5\ngini = 0.448\nsamples = 68\nvalue = [23, 45]\nclass = Turnover'),
#  Text(0.78125, 0.1, 'gini = 0.245\nsamples = 21\nvalue = [3, 18]\nclass = Turnover'),
#  Text(0.84375, 0.1, 'gini = 0.489\nsamples = 47\nvalue = [20.0, 27.0]\nclass = Turnover'),
#  Text(0.9375, 0.3, 'Tempo_de_empresa <= 0.5\ngini = 0.433\nsamples = 63\nvalue = [43, 20]\nclass = Não Turnover'),
#  Text(0.90625, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Turnover'),
#  Text(0.96875, 0.1, 'gini = 0.416\nsamples = 61\nvalue = [43, 18]\nclass = Não Turnover')]

# %%
# Cálculo do Desempenho do Modelo:

print(f'Acurácia: {round(accuracy_score(y, model.predict(x)), 2) * 100}%')
# Out:
# Acurácia: 87.0%
