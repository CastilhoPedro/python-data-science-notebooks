# %%
print("Primeiro Código")

# %%
import pandas as pd
import numpy as np
import matplotlib


np.random.seed(2)


x = np.random.rand(100)
y = 0.2 * x + 0.05 * np.random.rand(100)

# Criar o DataFrame
df = pd.DataFrame({'x': x, 'y': y})

matplotlib.pyplot.scatter(df['x'], df['y'], marker= 'o')
matplotlib.pyplot.show()

# %% [markdown]
# #Utilizando a biblioteca pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("base_vendas.csv", sep=',')
df.tail(15)
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  nome_loja  \
# 2985              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2986              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2987              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2988              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2989              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2990              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2991              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2992              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2993              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2994              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2995              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# ...

# %%
df = pd.read_csv("base_vendas_ponto_virgula.csv", sep= ';')
df

# %%
df = pd.read_csv("base_vendas_tab.tsv", sep= "\t")
df
# Out:
#     matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4               123456111       José Maria  Vendedor       CL001  Loja Matriz
# ..                    ...              ...       ...         ...          ...
# 95              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 96              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 97              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 98              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 99              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
# ...
